# %%
from faker import Faker
import pandas as pd
import numpy as np
import random
import datetime
import time

# %%
fake = Faker()

# %%
recipe_id=[]
recipe_name=[]
recipeSummary=[]
num_of_serving=[]
serving_size=[]
item_unit=[]
recipe_weight=[]
recipe_type_id=[]
recipe_notes=[]
prepare_time=[]
description=[]
total_carbohydrate=[]
total_protein=[]
total_energy=[]
total_lipid_fat=[]
recipe_image=[]
eqv=[]
micronutrient=[]
food_type=[]

# %%
for i in range(100000,100100):
  recipe_id.append("RP"+str(i))

for i in range(100):
  rname = random.choice([
    "Spaghetti Bolognese",
    "Chicken Alfredo Pasta",
    "Vegetarian Stir-Fry",
    "Grilled Salmon with Lemon",
    "Margherita Pizza",
    "Beef Tacos",
    "Chicken Caesar Salad",
    "Vegan Lentil Soup",
    "Shrimp Scampi",
    "Mushroom Risotto"
])
  recipe_name.append(rname)

for i in range(100):
  rsum = random.choice([
    "Classic Italian dish with ground beef, tomatoes, and herbs served over spaghetti.",
    "Creamy pasta dish with grilled chicken, Alfredo sauce, and Parmesan cheese.",
    "Healthy stir-fry with a mix of colorful vegetables and tofu or your choice of protein.",
    "Light and flavorful grilled salmon fillets drizzled with fresh lemon juice.",
    "Simple and delicious pizza with tomato sauce, fresh mozzarella, and basil.",
    "Tasty beef tacos with seasoned meat, lettuce, tomatoes, and cheese.",
    "Fresh and crisp salad with grilled chicken, romaine lettuce, and Caesar dressing.",
    "Hearty vegan lentil soup packed with vegetables and aromatic spices.",
    "Garlic-infused shrimp cooked in a white wine and lemon butter sauce.",
    "Creamy and savory mushroom risotto made with Arborio rice and mushrooms."
])
  recipeSummary.append(rsum)

for _ in range(100):
  nos = random.randint(1, 10)
  num_of_serving.append(str(nos))

for _ in range(100):
  ssize = random.choice([
    "200",
    "150",
    "160",
    "110",
    "130",
    "220",
    "210",
])
  serving_size.append(ssize)

for _ in range(100):
  iunit = random.choice([
    "ml",
    "gm",

])
  item_unit.append(iunit)

for _ in range(100):
  rw = random.choice([
    "200",
    "360",
    "160",
    "640",
    "840",
    "220",
    "1000",
])
  recipe_weight.append(rw)

for _ in range(100):
  rti = random.randint(10, 199)
  recipe_type_id.append(rti)

for i in range(100):
  rnote = random.choice([
    "Classic Italian dish with ground beef, tomatoes, and herbs served over spaghetti.",
    "Creamy pasta dish with grilled chicken, Alfredo sauce, and Parmesan cheese.",
    "Healthy stir-fry with a mix of colorful vegetables and tofu or your choice of protein.",
    "Light and flavorful grilled salmon fillets drizzled with fresh lemon juice.",
    "Simple and delicious pizza with tomato sauce, fresh mozzarella, and basil.",
    "Tasty beef tacos with seasoned meat, lettuce, tomatoes, and cheese.",
    "Fresh and crisp salad with grilled chicken, romaine lettuce, and Caesar dressing.",
    "Hearty vegan lentil soup packed with vegetables and aromatic spices.",
    "Garlic-infused shrimp cooked in a white wine and lemon butter sauce.",
    "Creamy and savory mushroom risotto made with Arborio rice and mushrooms."
])
  recipe_notes.append(rnote)

for _ in range(100):
  pt = random.choice([
    "5 min",
    "15 min",
    "25 min",
    "30 min",
    "10 min",
])
  prepare_time.append(pt)

for i in range(100):
  desc = random.choice([
    "Classic Italian dish with ground beef, tomatoes, and herbs served over spaghetti.",
    "Creamy pasta dish with grilled chicken, Alfredo sauce, and Parmesan cheese.",
    "Healthy stir-fry with a mix of colorful vegetables and tofu or your choice of protein.",
    "Light and flavorful grilled salmon fillets drizzled with fresh lemon juice.",
    "Simple and delicious pizza with tomato sauce, fresh mozzarella, and basil.",
    "Tasty beef tacos with seasoned meat, lettuce, tomatoes, and cheese.",
    "Fresh and crisp salad with grilled chicken, romaine lettuce, and Caesar dressing.",
    "Hearty vegan lentil soup packed with vegetables and aromatic spices.",
    "Garlic-infused shrimp cooked in a white wine and lemon butter sauce.",
    "Creamy and savory mushroom risotto made with Arborio rice and mushrooms."
])
  description.append(desc)

for i in range(100):
  carb = round(random.uniform(0, 300), 2)
  total_carbohydrate.append(carb)

for i in range(100):
  pro = round(random.uniform(0, 80), 2)
  total_protein.append(pro)

for i in range(100):
  en = random.randint(300, 1500)
  total_energy.append(en)

for i in range(100):
  lip = round(random.uniform(0, 50), 2)
  total_lipid_fat.append(lip)

for i in range(100):
  recipe_image.append(fake.image_url())

for i in range(100):
  food_type.append('recipe')

# %%
recipe_dict = {
  'recipe_id': recipe_id,
  'recipe_name': recipe_name,
  'recipeSummary': recipeSummary,
  'num_of_serving': num_of_serving,
  'serving_size': serving_size,
  'item_unit': item_unit,
  'recipe_weight': recipe_weight,
  'recipe_type_id': recipe_type_id,
  'recipe_notes': recipe_notes,
  'prepare_time': prepare_time,
  'description': description,
  'total_carbohydrate': total_carbohydrate,
  'total_protein': total_protein,
  'total_energy': total_energy,
  'total_lipid_fat': total_lipid_fat,
  'recipe_image': recipe_image,
  'food_type': food_type
}

# %%
recipe_df = pd.DataFrame(recipe_dict)

# %%
recipe_df.head()
# Out:
#   recipe_id            recipe_name  \
# 0  RP100000  Chicken Alfredo Pasta
# 1  RP100001      Vegan Lentil Soup
# 2  RP100002      Vegan Lentil Soup
# 3  RP100003       Margherita Pizza
# 4  RP100004             Beef Tacos
#
#                                        recipeSummary num_of_serving  \
# 0  Simple and delicious pizza with tomato sauce, ...              7
# 1  Tasty beef tacos with seasoned meat, lettuce, ...              5
# 2  Hearty vegan lentil soup packed with vegetable...             10
# 3  Hearty vegan lentil soup packed with vegetable...              3
# 4  Fresh and crisp salad with grilled chicken, ro...              2
#
#   serving_size item_unit recipe_weight  recipe_type_id  \
# 0          110        ml           160              87
# 1          130        gm          1000             145
# 2          110        ml           360             102
# 3          130        gm           360             188
# 4          160        gm           220              64
#
#                                         recipe_notes prepare_time  \
# 0  Garlic-infused shrimp cooked in a white wine a...       25 min
# 1  Creamy and savory mushroom risotto made with A...       10 min
# 2  Light and flavorful grilled salmon fillets dri...       15 min
# 3  Simple and delicious pizza with tomato sauce, ...       10 min
# 4  Classic Italian dish with ground beef, tomatoe...        5 min
#
#                                          description  total_carbohydrate  \
# 0  Healthy stir-fry with a mix of colorful vegeta...               25.49
# 1  Light and flavorful grilled salmon fillets dri...              189.09
# 2  Tasty beef tacos with seasoned meat, lettuce, ...              108.59
# 3  Light and flavorful grilled salmon fillets dri...              177.98
# 4  Simple and delicious pizza with tomato sauce, ...              222.64
#
#    total_protein  total_energy  total_lipid_fat  \
# 0          33.02           862            24.21
# 1          60.72           700            21.99
# 2          11.41          1172            33.66
# 3          44.46          1264            45.00
# 4           4.97          1383            34.80
#
#                       recipe_image food_type
# 0   https://dummyimage.com/793x574    recipe
# 1    https://picsum.photos/428/307    recipe
# 2   https://dummyimage.com/831x924    recipe
# 3  https://placekitten.com/466/365    recipe
# 4    https://picsum.photos/158/805    recipe

# %%
recipe_df.to_csv('datasets/Fake_datasets/hca_recipes.csv')
