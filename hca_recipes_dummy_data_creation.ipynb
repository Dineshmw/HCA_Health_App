# %%
from faker import Faker
import pandas as pd
import numpy as np
import random
import datetime
import time

# %%
# Loading the data
recipe_data = pd.read_csv('datasets/hca_recipes.csv')

# Get the column names
for column in recipe_data.columns:
    print(column)
# Out:
# id
# recipe_name
# recipeSummary
# recipe_slug
# num_of_serving
# serving_size
# item_unit
# recipe_weight
# recipe_type_id
# recipe_notes
# prepare_time
# description
# total_carbohydrate
# total_protein
# total_energy
# total_lipid_fat
# recipe_image
# eqv
# micronutrient
# food_type
# substitute_recipeids
# substitute_itemsids
# source
# fatsecret_id
# is_public
# short_url
# created_by
# updated_by
# deleted_by
# is_active
# is_deleted
# created_on
# updated_on
# deleted_on

# %%
fake = Faker()

# %%
recipe_id=[]
recipe_name=[]
recipeSummary=[]
num_of_serving=[]
serving_size=[]
item_unit=[]
recipe_weight=[]
recipe_type_id=[]
recipe_notes=[]
prepare_time=[]
description=[]
total_carbohydrate=[]
total_protein=[]
total_energy=[]
total_lipid_fat=[]
recipe_image=[]
eqv=[]
micronutrient=[]
food_type=[]
micronutrient =[]
substitute_recipeids=[]
substitute_itemsids=[]

# %%
for i in range(100000,100100):
  recipe_id.append("RP"+str(i))

for i in range(100):
  rname = random.choice([
    "Spaghetti Bolognese",
    "Chicken Alfredo Pasta",
    "Vegetarian Stir-Fry",
    "Grilled Salmon with Lemon",
    "Margherita Pizza",
    "Beef Tacos",
    "Chicken Caesar Salad",
    "Vegan Lentil Soup",
    "Shrimp Scampi",
    "Mushroom Risotto"
])
  recipe_name.append(rname)

for i in range(100):
  rsum = random.choice([
    "Classic Italian dish with ground beef, tomatoes, and herbs served over spaghetti.",
    "Creamy pasta dish with grilled chicken, Alfredo sauce, and Parmesan cheese.",
    "Healthy stir-fry with a mix of colorful vegetables and tofu or your choice of protein.",
    "Light and flavorful grilled salmon fillets drizzled with fresh lemon juice.",
    "Simple and delicious pizza with tomato sauce, fresh mozzarella, and basil.",
    "Tasty beef tacos with seasoned meat, lettuce, tomatoes, and cheese.",
    "Fresh and crisp salad with grilled chicken, romaine lettuce, and Caesar dressing.",
    "Hearty vegan lentil soup packed with vegetables and aromatic spices.",
    "Garlic-infused shrimp cooked in a white wine and lemon butter sauce.",
    "Creamy and savory mushroom risotto made with Arborio rice and mushrooms."
])
  recipeSummary.append(rsum)

for _ in range(100):
  nos = random.randint(1, 10)
  num_of_serving.append(str(nos))

for _ in range(100):
  ssize = random.choice([
    "200",
    "150",
    "160",
    "110",
    "130",
    "220",
    "210",
])
  serving_size.append(ssize)

for _ in range(100):
  iunit = random.choice([
    "ml",
    "gm",

])
  item_unit.append(iunit)

for _ in range(100):
  nos = random.randint(7, 450)
  eqv.append(str(nos))

for _ in range(100):
  rw = random.choice([
    "200",
    "360",
    "160",
    "640",
    "840",
    "220",
    "1000",
])
  recipe_weight.append(rw)

for _ in range(100):
  rti = random.randint(10, 199)
  recipe_type_id.append(rti)

for i in range(100):
  rnote = random.choice([
    "Classic Italian dish with ground beef, tomatoes, and herbs served over spaghetti.",
    "Creamy pasta dish with grilled chicken, Alfredo sauce, and Parmesan cheese.",
    "Healthy stir-fry with a mix of colorful vegetables and tofu or your choice of protein.",
    "Light and flavorful grilled salmon fillets drizzled with fresh lemon juice.",
    "Simple and delicious pizza with tomato sauce, fresh mozzarella, and basil.",
    "Tasty beef tacos with seasoned meat, lettuce, tomatoes, and cheese.",
    "Fresh and crisp salad with grilled chicken, romaine lettuce, and Caesar dressing.",
    "Hearty vegan lentil soup packed with vegetables and aromatic spices.",
    "Garlic-infused shrimp cooked in a white wine and lemon butter sauce.",
    "Creamy and savory mushroom risotto made with Arborio rice and mushrooms."
])
  recipe_notes.append(rnote)

for _ in range(100):
  pt = random.choice([
    "5 min",
    "15 min",
    "25 min",
    "30 min",
    "10 min",
])
  prepare_time.append(pt)

for i in range(100):
  desc = random.choice([
    "Classic Italian dish with ground beef, tomatoes, and herbs served over spaghetti.",
    "Creamy pasta dish with grilled chicken, Alfredo sauce, and Parmesan cheese.",
    "Healthy stir-fry with a mix of colorful vegetables and tofu or your choice of protein.",
    "Light and flavorful grilled salmon fillets drizzled with fresh lemon juice.",
    "Simple and delicious pizza with tomato sauce, fresh mozzarella, and basil.",
    "Tasty beef tacos with seasoned meat, lettuce, tomatoes, and cheese.",
    "Fresh and crisp salad with grilled chicken, romaine lettuce, and Caesar dressing.",
    "Hearty vegan lentil soup packed with vegetables and aromatic spices.",
    "Garlic-infused shrimp cooked in a white wine and lemon butter sauce.",
    "Creamy and savory mushroom risotto made with Arborio rice and mushrooms."
])
  description.append(desc)

for i in range(100):
  carb = round(random.uniform(0, 300), 2)
  total_carbohydrate.append(carb)

for i in range(100):
  pro = round(random.uniform(0, 80), 2)
  total_protein.append(pro)

for i in range(100):
  en = random.randint(300, 1500)
  total_energy.append(en)

for i in range(100):
  lip = round(random.uniform(0, 50), 2)
  total_lipid_fat.append(lip)

for i in range(100):
  recipe_image.append(fake.image_url())

for i in range(100):
  food_type.append('recipe')
for i in range(100):
  micronutrient.append(None)

for i in range(100000,100100):
  substitute_recipeids.append('SR' + str(i))
  substitute_itemsids.append(None)

# %%
recipe_dict = {
  'recipe_id': recipe_id,
  'recipe_name': recipe_name,
  'recipeSummary': recipeSummary,
  'num_of_serving': num_of_serving,
  'serving_size': serving_size,
  'item_unit': item_unit,
  'recipe_weight': recipe_weight,
  'recipe_type_id': recipe_type_id,
  'recipe_notes': recipe_notes,
  'prepare_time': prepare_time,
  'description': description,
  'total_carbohydrate': total_carbohydrate,
  'eqv':eqv,
  'total_protein': total_protein,
  'total_energy': total_energy,
  'total_lipid_fat': total_lipid_fat,
  'recipe_image': recipe_image,
  'food_type': food_type,
  'substitute_itemsids':substitute_itemsids,
  'substitute_recipeids':substitute_recipeids,
  'micronutrient':micronutrient
}

# %%
recipe_df = pd.DataFrame(recipe_dict)

# %%
recipe_df.head()
# Out:
#   recipe_id                recipe_name  \
# 0  RP100000                 Beef Tacos
# 1  RP100001  Grilled Salmon with Lemon
# 2  RP100002           Margherita Pizza
# 3  RP100003           Margherita Pizza
# 4  RP100004                 Beef Tacos
#
#                                        recipeSummary num_of_serving  \
# 0  Healthy stir-fry with a mix of colorful vegeta...              5
# 1  Classic Italian dish with ground beef, tomatoe...              2
# 2  Simple and delicious pizza with tomato sauce, ...              7
# 3  Tasty beef tacos with seasoned meat, lettuce, ...              1
# 4  Classic Italian dish with ground beef, tomatoe...              5
#
#   serving_size item_unit recipe_weight  recipe_type_id  \
# 0          130        ml           360              21
# 1          110        ml           840              11
# 2          110        ml           200              85
# 3          160        ml          1000             185
# ...

# %%
recipe_df.to_csv('datasets/Fake_datasets/hca_recipes.csv',index=False)
