# %%
from faker import Faker
import pandas as pd
import numpy as np
import random
import datetime
import time

# %%
# Loading the data
hca_food_logs_data = pd.read_csv('datasets/hca_food_logs.csv')
for column in hca_food_logs_data.columns:
    print(column)
# Out:
# id
# log_date
# item_id
# food_time
# food_type
# log_time
# energy
# protein
# carbohydrate
# lipid_fat
# item_unit
# item_quantity
# created_by
# updated_by
# deleted_by
# exceeded_calories
# comments
# comment_on
# comment_by
# liked_substitute
# is_active
# is_deleted
# created_on
# updated_on
# deleted_on
# c_log_time

# %%
fake = Faker()

# %%
log_id=[]
log_date=[]
item_id=[]
food_time=[]
food_type=[]
log_time=[]
energy=[]
protein=[]
carbohydrate=[]
lipid_fat=[]
item_unit=[]
item_quantity=[]
created_by=[]

# %%
for i in range(100000,100100):
  log_id.append("LI"+str(i))
    
for _ in range(100):
  log_date.append(fake.date_this_year())

for _ in range(100):
    time = fake.unix_time()
    food_time.append(time)

for _ in range(100):
    type = random.choice(["food_item", "recipe"])
    if(type == "food_item"):
        iid = random.choice(['FI100015', 'FI100016', 'FI100017', 'FI100018', 'FI100019', 'FI100020', 'FI100021','FI10002','FI100023', 'FI100024', 'FI100025', 'FI100026', 'FI100027', 'FI100028','FI100029','FI100030','FI100031','FI100032','FI100033','FI100034','FI100035','FI100036','FI100037','FI100038', 'FI100039', 'FI100040', 'FI100041', 'FI100042', 'FI100043', 'FI100044', 'FI100045', 'FI100046', 'FI100047', 'FI100048', 'FI100049', 'FI100050', 'FI100051', 'FI100052', 'FI100053', 'FI100054', 'FI100055', 'FI100056', 'FI100057', 'FI100058', 'FI100059', 'FI100060', 'FI100061', 'FI100062', 'FI100063', 'FI100064', 'FI100065', 'FI100066', 'FI100067', 'FI100068', 'FI100069', 'FI100070', 'FI100071', 'FI100072', 'FI100073', 'FI100074', 'FI100075', 'FI100076', 'FI100077', 'FI100078', 'FI100079', 'FI100080', 'FI100081', 'FI100082', 'FI100083'])
        item_id.append(iid)
    elif(type == "recipe"):
        iid = random.choice(['RP100000', 'RP100001', 'RP100002', 'RP100003', 'RP100004', 'RP100005', 'RP100006', 'RP100007', 'RP100008', 'RP100009', 'RP100010', 'RP100011', 'RP100012', 'RP100013', 'RP100014', 'RP100015', 'RP100016', 'RP100017', 'RP100018', 'RP100019', 'RP100020', 'RP100021', 'RP100022', 'RP100023', 'RP100024', 'RP100025', 'RP100026', 'RP100027', 'RP100028', 'RP100029', 'RP100030', 'RP100031', 'RP100032', 'RP100033', 'RP100034', 'RP100035', 'RP100036', 'RP100037', 'RP100038', 'RP100039', 'RP100040', 'RP100041', 'RP100042', 'RP100043', 'RP100044', 'RP100045', 'RP100046', 'RP100047', 'RP100048', 'RP100049', 'RP100050', 'RP100051', 'RP100052', 'RP100053', 'RP100054', 'RP100055', 'RP100056', 'RP100057', 'RP100058', 'RP100059', 'RP100060', 'RP100061', 'RP100062', 'RP100063', 'RP100064', 'RP100065', 'RP100066', 'RP100067', 'RP100068', 'RP100069', 'RP100070', 'RP100071', 'RP100072', 'RP100073', 'RP100074', 'RP100075', 'RP100076', 'RP100077', 'RP100078', 'RP100079', 'RP100080', 'RP100081', 'RP100082', 'RP100083', 'RP100084', 'RP100085', 'RP100086', 'RP100087', 'RP100088', 'RP100089', 'RP100090', 'RP100091', 'RP100092', 'RP100093', 'RP100094', 'RP100095', 'RP100096', 'RP100097', 'RP100098', 'RP100099'])
        item_id.append(iid) 
    food_type.append(type)

for _ in range(100):
  lt = random.randint(1, 15)
  log_time.append(str(lt))

for i in range(100):
  en = random.randint(80, 300)
  energy.append(en)

for i in range(100):
  pro = round(random.uniform(0, 50), 2)
  protein.append(pro)

for i in range(100):
  carb = round(random.uniform(0, 50), 2)
  carbohydrate.append(carb)

for i in range(100):
  lip = round(random.uniform(0, 50), 2)
  lipid_fat.append(lip)

for _ in range(100):
  uni = random.choice(["1 medium", "gm", "ml", "1 slice"])
  item_unit.append(uni)

for i in range(100):
  qua = random.randint(1, 300)
  item_quantity.append(qua)

for _ in range(100):
  cby = random.choice(['U100000', 'U100001', 'U100002', 'U100003', 'U100004', 'U100005', 'U100006', 'U100007', 'U100008', 'U100009', 'U100010', 'U100011', 'U100012', 'U100013', 'U100014', 'U100015', 'U100016', 'U100017', 'U100018', 'U100019', 'U100020', 'U100021', 'U100022', 'U100023', 'U100024', 'U100025', 'U100026', 'U100027', 'U100028', 'U100029', 'U100030', 'U100031', 'U100032', 'U100033', 'U100034', 'U100035', 'U100036', 'U100037', 'U100038', 'U100039', 'U100040', 'U100041', 'U100042', 'U100043', 'U100044', 'U100045', 'U100046', 'U100047', 'U100048', 'U100049', 'U100050', 'U100051', 'U100052', 'U100053', 'U100054', 'U100055', 'U100056', 'U100057', 'U100058', 'U100059', 'U100060', 'U100061', 'U100062', 'U100063', 'U100064', 'U100065', 'U100066', 'U100067', 'U100068', 'U100069', 'U100070', 'U100071', 'U100072', 'U100073', 'U100074', 'U100075', 'U100076', 'U100077', 'U100078', 'U100079', 'U100080', 'U100081', 'U100082', 'U100083', 'U100084', 'U100085', 'U100086', 'U100087', 'U100088'])
  created_by.append(cby)

# %%
print(log_id)
# Out:
# ['LI100000', 'LI100001', 'LI100002', 'LI100003', 'LI100004', 'LI100005', 'LI100006', 'LI100007', 'LI100008', 'LI100009', 'LI100010', 'LI100011', 'LI100012', 'LI100013', 'LI100014', 'LI100015', 'LI100016', 'LI100017', 'LI100018', 'LI100019', 'LI100020', 'LI100021', 'LI100022', 'LI100023', 'LI100024', 'LI100025', 'LI100026', 'LI100027', 'LI100028', 'LI100029', 'LI100030', 'LI100031', 'LI100032', 'LI100033', 'LI100034', 'LI100035', 'LI100036', 'LI100037', 'LI100038', 'LI100039', 'LI100040', 'LI100041', 'LI100042', 'LI100043', 'LI100044', 'LI100045', 'LI100046', 'LI100047', 'LI100048', 'LI100049', 'LI100050', 'LI100051', 'LI100052', 'LI100053', 'LI100054', 'LI100055', 'LI100056', 'LI100057', 'LI100058', 'LI100059', 'LI100060', 'LI100061', 'LI100062', 'LI100063', 'LI100064', 'LI100065', 'LI100066', 'LI100067', 'LI100068', 'LI100069', 'LI100070', 'LI100071', 'LI100072', 'LI100073', 'LI100074', 'LI100075', 'LI100076', 'LI100077', 'LI100078', 'LI100079', 'LI100080', 'LI100081', 'LI100082', '
# ...

# %%
food_log_dict = {
        "log_date": log_date,
        "item_id": item_id,
        "food_time": food_time,
        "food_type": food_type,
        "log_time": log_time,
        "energy": energy,
        "protein": protein,
        "carbohydrate": carbohydrate,
        "lipid_fat": lipid_fat,
        "item_unit": item_unit,
        "item_quantity": item_quantity,
        "created_by": created_by
    }

# %%
food_log_df = pd.DataFrame(food_log_dict)

# %%
food_log_df.head(20)
# Out:
#       log_date   item_id   food_time  food_type log_time  energy  protein  \
# 0   2024-01-18  FI100066   982128804  food_item       13     205    21.87
# 1   2024-01-13  RP100037   653263759     recipe        8     251    41.70
# 2   2024-01-13  RP100098   614655379     recipe       12     253    43.84
# 3   2024-01-19  FI100057  1291072078  food_item       12     256     5.70
# 4   2024-01-27  FI100059   782117572  food_item       13     211    13.64
# 5   2024-01-21  FI100042   932195234  food_item        2     199    25.54
# 6   2024-01-04  RP100001   995278561     recipe       10     149    34.63
# 7   2024-01-25  RP100066  1306949443     recipe        4      81    21.34
# 8   2024-01-06  RP100042   405951120     recipe        4     242     1.86
# 9   2024-01-16  RP100043   382995846     recipe        9     167     1.55
# 10  2024-01-17  FI100074  1564103280  food_item        8     138    35.86
# 11  2024-01-10  RP100065    52106565     recipe       10     122    25.76
# ...

# %%
food_log_df.to_csv('datasets/Fake_datasets/hca_food_logs.csv',index=False)
