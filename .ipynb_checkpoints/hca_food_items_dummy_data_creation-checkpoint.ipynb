# %%
from faker import Faker
import pandas as pd
import numpy as np
import random
import datetime
import time

# %%
hca_food_items = pd.read_csv('datasets/hca_food_items.csv')
for column in hca_food_items.columns:
    print(column)
# Out:
# id
# fdc_id
# item_name
# group_name
# ndb_number
# upc_number
# manufacture
# food_category
# source
# energy
# protein
# cholesterol
# carbohydrate
# lipid_fat
# sugar
# sodium
# item_unit
# item_quantity
# description
# food_type
# is_detail_available
# substitute_itemsids
# substitute_recipeids
# created_by
# updated_by
# deleted_by
# is_active
# is_deleted
# created_on
# updated_on
# deleted_on

# %%
fake = Faker()

# %%
fdc_id=[]
item_name=[]
ndb_number=[]
upc_number=[]
manufacture=[]
food_category=[]
source=[]
energy=[]
protein=[]
cholesterol=[]
carbohydrate=[]
lipid_fat=[]
description=[]
is_detail_available=[]
substitute_itemsids=[]
substitute_recipeids=[]
food_type=[]
item_unit=[]
item_quantity=[]

# %%
for i in range(100000,100100):
    fdc_id.append('FI' + str(i))

for i in range(100):
  item = random.choice([ 'Pizza',
    'Burger',
    'Pasta',
    'Salad',
    'Sushi',
    'Tacos',
    'Chicken Curry',
    'Ice Cream',
    'Chocolate Cake',
    'Fruit Smoothie',
    'Grilled Salmon',
    'Vegetable Stir-Fry',
    'Cheese Sandwich',
    'Shrimp Scampi',
    'Mango Sorbet',
    'Beef Tacos',
    'Caesar Salad',
    'Lasagna',
    'Tomato Soup',])
  item_name.append(item)

for i in range(450000,450100):
  ndb_number.append(str(i))

for i in range(100):
  upc = random.randint(5051379009526, 5051379035044)
  upc_number.append(str(upc))

for _ in range(100):
  manu = random.choice(["G. T. Japan, Inc.", "Fresh & Easy"])
  manufacture.append(manu)

for _ in range(100):
  cate = random.choice(["Ice Cream & Frozen Yogurt", "BBQ & Cheese Sauce"])
  food_category.append(cate)

for _ in range(100):
  source.append("usda")

for i in range(100):
  eng = random.randint(100, 220)
  energy.append(str(eng))

for i in range(100):
  pro = random.choice(['0', '2.5'])
  protein.append(pro)

for i in range(100):
  cho = random.choice(['0', '25'])
  cholesterol.append(cho)

for i in range(100):
  carb = round(random.uniform(0, 50), 2)
  carbohydrate.append(carb)

for i in range(100):
  lip = round(random.uniform(0, 50), 2)
  lipid_fat.append(lip)

for i in range(100):
  item_unit.append('g')

for i in range(100):
  desc = fake.sentence()
  description.append(desc)

for i in range(100):
  item_quantity.append('100')

for i in range(100):
  is_detail_available.append('1')

for i in range(100000,100100):
  substitute_itemsids.append('SF' + str(i))
  substitute_recipeids.append(None)

for i in range(100):
    food_type.append('food_item')

# %%
Food_item_dictionary = {
    'fdc_id': fdc_id,
    'item_name': item_name,
    'ndb_number': ndb_number,
    'upc_number': upc_number,
    'manufacture': manufacture,
    'food_category': food_category,
    'source': source,
    'energy': energy,
    'protein': protein,
    'cholesterol': cholesterol,
    'carbohydrate': carbohydrate,
    'lipid_fat': lipid_fat,
    'description': description,
    'item_quantity': item_quantity,
    'is_detail_available': is_detail_available,
    'substitute_itemsids':substitute_itemsids,
    'substitute_recipeids':substitute_recipeids,
    'food_type':food_type
}

# %%
for key, value in Food_item_dictionary.items():
    print(f'Key: {key}, Value: {len(value)}')
# Out:
# Key: fdc_id, Value: 100
# Key: item_name, Value: 100
# Key: ndb_number, Value: 100
# Key: upc_number, Value: 100
# Key: manufacture, Value: 100
# Key: food_category, Value: 100
# Key: source, Value: 100
# Key: energy, Value: 100
# Key: protein, Value: 100
# Key: cholesterol, Value: 100
# Key: carbohydrate, Value: 100
# Key: lipid_fat, Value: 100
# Key: description, Value: 100
# Key: item_quantity, Value: 100
# Key: is_detail_available, Value: 100
# Key: substitute_itemsids, Value: 100
# Key: substitute_recipeids, Value: 100
# Key: food_type, Value: 100

# %%
food_item_df = pd.DataFrame(Food_item_dictionary)

# %%
food_item_df.head()
# Out:
#      fdc_id       item_name ndb_number     upc_number        manufacture  \
# 0  FI100000           Pasta     450000  5051379024915  G. T. Japan, Inc.
# 1  FI100001           Sushi     450001  5051379011003  G. T. Japan, Inc.
# 2  FI100002           Pasta     450002  5051379031147  G. T. Japan, Inc.
# 3  FI100003         Lasagna     450003  5051379018551  G. T. Japan, Inc.
# 4  FI100004  Fruit Smoothie     450004  5051379012383  G. T. Japan, Inc.
#
#                food_category source energy protein cholesterol  carbohydrate  \
# 0  Ice Cream & Frozen Yogurt   usda    157       0           0         23.03
# 1         BBQ & Cheese Sauce   usda    178     2.5          25         46.47
# 2  Ice Cream & Frozen Yogurt   usda    150     2.5           0         13.44
# 3         BBQ & Cheese Sauce   usda    182       0          25         39.82
# 4  Ice Cream & Frozen Yogurt   usda    201       0          25          6.95
#
#    lipid_fat                                        description item_quantity  \
# 0       4.11                  Phone anything after tonight ten.           100
# 1      19.57        Program government reason you article four.           100
# 2      20.89  Various language popular participant treat off...           100
# 3      47.17                           Head serious see step a.           100
# 4      11.76                                  Red type on away.           100
#
#   is_detail_available substitute_itemsids substitute_recipeids  food_type
# 0                   1            SF100000                 None  food_item
# 1                   1            SF100001                 None  food_item
# 2                   1            SF100002                 None  food_item
# 3                   1            SF100003                 None  food_item
# 4                   1            SF100004                 None  food_item

# %%
food_item_df.to_csv('datasets/Fake_datasets/hca_food_items.csv')
