# %%
from faker import Faker
import pandas as pd
import numpy as np
import random
import datetime
import time

# %%
# Loading the data
hca_food_substitute_data = pd.read_csv('datasets/hca_food_substitute.csv')

# Get the column names
columns_list = hca_food_substitute_data.columns.tolist()
columns_list
# Out:
# ['id',
#  'user_id',
#  'food_log_id',
#  'foodlog_item_id',
#  'item_id',
#  'food_time',
#  'food_type',
#  'as_ingradient',
#  'energy',
#  'protein',
#  'carbohydrate',
#  'lipid_fat',
#  'item_unit',
#  'item_quantity',
#  'created_by',
#  'updated_by',
#  'deleted_by',
#  'is_active',
#  'is_deleted',
#  'created_on',
#  'updated_on',
#  'deleted_on']

# %%
fake = Faker()

# %%
substitute_id=[]
user_id=[]
food_log_id =[]
food_item_id=[]
food_time=[]
as_ingradient=[]
carbohydrate=[]
protein=[]
energy=[]
lipid_fat=[]
quantity=[]
unit=[]
eqv=[]
food_type=[]
substitute_item_id=[]
substitute_type=[]

# %%
for i in range(100000,100100):
  substitute_id.append("SI"+str(i))
    
for _ in range(100):
  cby = random.choice(['U100000', 'U100001', 'U100002', 'U100003', 'U100004', 'U100005', 'U100006', 'U100007', 'U100008', 'U100009', 'U100010', 'U100011', 'U100012', 'U100013', 'U100014', 'U100015', 'U100016', 'U100017', 'U100018', 'U100019', 'U100020', 'U100021', 'U100022', 'U100023', 'U100024', 'U100025', 'U100026', 'U100027', 'U100028', 'U100029', 'U100030', 'U100031', 'U100032', 'U100033', 'U100034', 'U100035', 'U100036', 'U100037', 'U100038', 'U100039', 'U100040', 'U100041', 'U100042', 'U100043', 'U100044', 'U100045', 'U100046', 'U100047', 'U100048', 'U100049', 'U100050', 'U100051', 'U100052', 'U100053', 'U100054', 'U100055', 'U100056', 'U100057', 'U100058', 'U100059', 'U100060', 'U100061', 'U100062', 'U100063', 'U100064', 'U100065', 'U100066', 'U100067', 'U100068', 'U100069', 'U100070', 'U100071', 'U100072', 'U100073', 'U100074', 'U100075', 'U100076', 'U100077', 'U100078', 'U100079', 'U100080', 'U100081', 'U100082', 'U100083', 'U100084', 'U100085', 'U100086', 'U100087', 'U100088'])
  user_id.append(cby)

for i in range(100000,100100):
  food_log_id.append("LI"+str(i))
    
    
for _ in range(100):
    iid = random.choice(['FI100015', 'FI100016', 'FI100017', 'FI100018', 'FI100019', 'FI100020', 'FI100021','FI10002','FI100023', 'FI100024', 'FI100025', 'FI100026', 'FI100027', 'FI100028','FI100029','FI100030','FI100031','FI100032','FI100033','FI100034','FI100035','FI100036','FI100037','FI100038', 'FI100039', 'FI100040', 'FI100041', 'FI100042', 'FI100043', 'FI100044', 'FI100045', 'FI100046', 'FI100047', 'FI100048', 'FI100049', 'FI100050', 'FI100051', 'FI100052', 'FI100053', 'FI100054', 'FI100055', 'FI100056', 'FI100057', 'FI100058', 'FI100059', 'FI100060', 'FI100061', 'FI100062', 'FI100063', 'FI100064', 'FI100065', 'FI100066', 'FI100067', 'FI100068', 'FI100069', 'FI100070', 'FI100071', 'FI100072', 'FI100073', 'FI100074', 'FI100075', 'FI100076', 'FI100077', 'FI100078', 'FI100079', 'FI100080', 'FI100081', 'FI100082', 'FI100083'])
    food_item_id.append(iid)
    
for _ in range(100):
  time = fake.unix_time()
  food_time.append(time)

for _ in range(100):
  boolean = random.choice([
    "Yes",
    "No",
])
  as_ingradient.append(boolean)

for _ in range(100):
  nos = random.randint(150, 250)
  energy.append(str(nos))


for _ in range(100):
  nos = random.randint(10, 50)
  carbohydrate.append(str(nos))

for _ in range(100):
  nos = random.randint(10, 50)
  protein.append(str(nos))

for _ in range(100):
  nos = random.randint(5, 10)
  lipid_fat.append(str(nos))
    
for _ in range(100):
  quantites = random.choice([
    "200",
    "150",
    "160",
    "110",
    "130",
    "220",
    "210",
])
  quantity.append(quantites)

for _ in range(100):
  iunit = random.choice([
    "ml",
    "gm",

])
  unit.append(iunit)

# %%
substitute_dict = {
  'substitute_id': substitute_id,
  'user_id': user_id,
  'food_log_id': food_log_id,
  'food_item_id': food_item_id,
  'food_time': food_time,
  'as_ingradient': as_ingradient,
  'energy': energy,
  'carbohydrate': carbohydrate,
  'protein': protein,
  'energy': energy,
  'lipid_fat': lipid_fat,
  'quantity': quantity,
  'unit':unit,
}

# %%
for key, value in substitute_dict.items():
    print(f'Key: {key}, Value: {len(value)}')
# Out:
# Key: substitute_id, Value: 100
# Key: user_id, Value: 100
# Key: food_log_id, Value: 100
# Key: food_item_id, Value: 100
# Key: food_time, Value: 100
# Key: as_ingradient, Value: 100
# Key: energy, Value: 100
# Key: carbohydrate, Value: 100
# Key: protein, Value: 100
# Key: lipid_fat, Value: 100
# Key: quantity, Value: 100
# Key: unit, Value: 100

# %%
substitute_df = pd.DataFrame(substitute_dict)

# %%
substitute_df.head()
# Out:
#   substitute_id  user_id food_log_id food_item_id   food_time as_ingradient  \
# 0      SI100000  U100079    LI100000     FI100017  1270826222            No
# 1      SI100001  U100079    LI100001     FI100031   499594063           Yes
# 2      SI100002  U100044    LI100002     FI100051   269896340            No
# 3      SI100003  U100057    LI100003     FI100059     2624502            No
# 4      SI100004  U100061    LI100004     FI100028   538156434            No
#
#   energy carbohydrate protein lipid_fat quantity unit
# 0    219           29      18         6      130   ml
# 1    154           20      26         8      160   ml
# 2    187           34      46         9      130   ml
# 3    206           19      46         6      220   ml
# 4    208           43      15         5      150   ml

# %%
substitute_df.to_csv('datasets/Fake_datasets/hca_food_substitute.csv', index=False)
